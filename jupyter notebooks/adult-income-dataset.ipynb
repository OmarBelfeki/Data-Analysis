# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt

import warnings

warnings.filterwarnings(action="ignore")


# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/adult-income-dataset/adult.csv

# %%
data = pd.read_csv("/kaggle/input/adult-income-dataset/adult.csv")

# %% [markdown]
# <h1>Display Top 10 Rows of The Dataset

# %%
data.head(10)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18                 ?  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29                 ?  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996       7th-8th                4
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %% [markdown]
# <h1>Check Last 10 Rows of The Dataset

# %%
data.tail(10)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 48832   32       Private   34066          10th                6
# 48833   43       Private   84661     Assoc-voc               11
# 48834   32       Private  116138       Masters               14
# 48835   53       Private  321865       Masters               14
# 48836   22       Private  310152  Some-college               10
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship  \
# 48832  Married-civ-spouse  Handlers-cleaners        Husband
# 48833  Married-civ-spouse              Sales        Husband
# 48834       Never-married       Tech-support  Not-in-family
# ...

# %% [markdown]
# <h1>Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
data.shape
# Out:
# (48842, 15)

# %% [markdown]
# <h1>Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %% [markdown]
# <h1>Fetch Random Sample From the Dataset (50%)

# %%
data.sample(frac=0.5)
# Out:
#        age    workclass  fnlwgt  education  educational-num  \
# 42893   62    State-gov  199198  Assoc-voc               11
# 44494   27    Local-gov  116662    HS-grad                9
# 11014   32      Private  130007       10th                6
# 34224   36  Federal-gov  192150    HS-grad                9
# 9706    20      Private  152189    HS-grad                9
# ...    ...          ...     ...        ...              ...
# 6527    24      Private  478457       11th                7
# 16283   38      Private  215646    HS-grad                9
# 6826    28      Private  228075    5th-6th                3
# 43304   58      Private  314092  Assoc-voc               11
# 13828   59      Private  128258    HS-grad                9
#
#            marital-status         occupation   relationship   race  gender  \
# 42893             Widowed    Exec-managerial      Unmarried  Black  Female
# 44494  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# ...

# %% [markdown]
# <h1>Check Null Values In The Dataset

# %%
data.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
sns.heatmap(data.isnull());

# %% [markdown]
# <h1>Perform Data Cleaning [ Replace '?' with NaN ]

# %%
data.isin(["?"]).sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
data.replace(to_replace="?", value=np.nan, inplace=True)

# %%
data.isin(["?"]).sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %% [markdown]
# <h1>Drop all The Missing Values

# %%
data.dropna(inplace=True)

# %%
data.shape
# Out:
# (45222, 15)

# %% [markdown]
# <h1>Check For Duplicate Data and Drop Them

# %%
data.duplicated().any()
# Out:
# True

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <h1>Get Overall Statistics About The Dataframe

# %%
data.describe(include="all")
# Out:
#                  age workclass        fnlwgt education  educational-num  \
# count   45175.000000     45175  4.517500e+04     45175     45175.000000
# unique           NaN         7           NaN        16              NaN
# top              NaN   Private           NaN   HS-grad              NaN
# freq             NaN     33262           NaN     14770              NaN
# mean       38.556170       NaN  1.897388e+05       NaN        10.119314
# std        13.215349       NaN  1.056524e+05       NaN         2.551740
# min        17.000000       NaN  1.349200e+04       NaN         1.000000
# 25%        28.000000       NaN  1.173925e+05       NaN         9.000000
# 50%        37.000000       NaN  1.783120e+05       NaN        10.000000
# 75%        47.000000       NaN  2.379030e+05       NaN        13.000000
# max        90.000000       NaN  1.490400e+06       NaN        16.000000
#
#             marital-status    occupation relationship   race gender  \
# ...

# %% [markdown]
# <h1>Drop The Columns education-num, capital-gain, and capital-loss

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
data.drop(columns=["educational-num", "capital-gain", "capital-loss"], inplace=True)

# %%
data.head()
# Out:
#    age  workclass  fnlwgt     education      marital-status  \
# 0   25    Private  226802          11th       Never-married
# 1   38    Private   89814       HS-grad  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3   44    Private  160323  Some-college  Married-civ-spouse
# 5   34    Private  198693          10th       Never-married
#
#           occupation   relationship   race gender  hours-per-week  \
# 0  Machine-op-inspct      Own-child  Black   Male              40
# 1    Farming-fishing        Husband  White   Male              50
# 2    Protective-serv        Husband  White   Male              40
# 3  Machine-op-inspct        Husband  Black   Male              40
# 5      Other-service  Not-in-family  White   Male              30
#
#   native-country income
# 0  United-States  <=50K
# 1  United-States  <=50K
# 2  United-States   >50K
# 3  United-States   >50K
# 5  United-States  <=50K

# %% [markdown]
# <h1>What Is The Distribution of Age Column?

# %%
plt.figure(figsize=(19, 18))
data.age.value_counts().plot.barh()
# Out:
# <Axes: ylabel='age'>

# %% [markdown]
# <h1>Find Total Number of Persons Having Age Between 17 To 48 (Inclusive) Using Between Method

# %%
data[data.age.between(17, 48)].shape[0]
# Out:
# 34858

# %% [markdown]
# <h1>What is The Distribution of Workclass Column?

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
data.workclass.value_counts().plot.barh()
# Out:
# <Axes: ylabel='workclass'>

# %% [markdown]
# <h1>How Many Persons Having Bachelors and Masters Degree?

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
data.head()
# Out:
#    age  workclass  fnlwgt     education      marital-status  \
# 0   25    Private  226802          11th       Never-married
# 1   38    Private   89814       HS-grad  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3   44    Private  160323  Some-college  Married-civ-spouse
# 5   34    Private  198693          10th       Never-married
#
#           occupation   relationship   race gender  hours-per-week  \
# 0  Machine-op-inspct      Own-child  Black   Male              40
# 1    Farming-fishing        Husband  White   Male              50
# 2    Protective-serv        Husband  White   Male              40
# 3  Machine-op-inspct        Husband  Black   Male              40
# 5      Other-service  Not-in-family  White   Male              30
#
#   native-country income
# 0  United-States  <=50K
# 1  United-States  <=50K
# 2  United-States   >50K
# 3  United-States   >50K
# 5  United-States  <=50K

# %%
data[data["education"].str.contains("bachelors", case=False) | data["education"].str.contains("masters", case=False)].shape[0]
# Out:
# 10072

# %% [markdown]
# <h1>Bivariate Analsis

# %%
corr = data.corr(numeric_only=True)
corr
# Out:
#                      age    fnlwgt  hours-per-week
# age             1.000000 -0.075590        0.101604
# fnlwgt         -0.075590  1.000000       -0.018712
# hours-per-week  0.101604 -0.018712        1.000000

# %%
# Scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(data['age'], data['fnlwgt'])
plt.title('Scatter Plot of Age vs fnlwgt')
plt.xlabel('Age')
plt.ylabel('fnlwgt')
plt.show()

# %%
# Scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(data['age'], data['hours-per-week'])
plt.title('Scatter Plot of Age vs hours-per-week')
plt.xlabel('Age')
plt.ylabel('hours-per-week')
plt.show()

# %%
# Pair plot
sns.pairplot(data)
plt.title('Pair Plot')
plt.show()

# %% [markdown]
# <h1>Replace Age Values With 0 and 1

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
data.income.value_counts()
# Out:
# income
# <=50K    33973
# >50K     11202
# Name: count, dtype: int64

# %%
data["salary"] = data["income"].replace({"<=50K": 0, ">50K": 1})

# %%
data.head()
# Out:
#    age  workclass  fnlwgt     education      marital-status  \
# 0   25    Private  226802          11th       Never-married
# 1   38    Private   89814       HS-grad  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3   44    Private  160323  Some-college  Married-civ-spouse
# 5   34    Private  198693          10th       Never-married
#
#           occupation   relationship   race gender  hours-per-week  \
# 0  Machine-op-inspct      Own-child  Black   Male              40
# 1    Farming-fishing        Husband  White   Male              50
# 2    Protective-serv        Husband  White   Male              40
# 3  Machine-op-inspct        Husband  Black   Male              40
# 5      Other-service  Not-in-family  White   Male              30
#
#   native-country income  salary
# 0  United-States  <=50K       0
# 1  United-States  <=50K       0
# 2  United-States   >50K       1
# 3  United-States   >50K       1
# 5  United-States  <=50K       0

# %% [markdown]
# <h1>Which Workclass Getting The Highest Salary?

# %%
data.groupby("workclass")["salary"].sum().sort_values(ascending=False).plot.barh()
plt.xlabel("salary")
# Out:
# Text(0.5, 0, 'salary')

# %% [markdown]
# <h1>How Has Better Chance To Get Salary greater than 50K Male or Female?

# %%
data[data['income'] == ">50K"]["gender"].value_counts()
# Out:
# gender
# Male      9533
# Female    1669
# Name: count, dtype: int64

# %% [markdown]
# <h1>Covert workclass Columns Datatype To Category Datatype

# %%
data.workclass = data.workclass.astype("category")

# %%
data.dtypes
# Out:
# age                  int64
# workclass         category
# fnlwgt               int64
# education           object
# marital-status      object
# occupation          object
# relationship        object
# race                object
# gender              object
# hours-per-week       int64
# native-country      object
# income              object
# salary               int64
# dtype: object
